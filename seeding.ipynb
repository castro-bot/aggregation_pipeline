# %% [markdown]
# <a href="https://colab.research.google.com/github/castro-bot/aggregation_pipeline/blob/main/seeding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "pymongo[srv]==3.12"

from getpass import getpass
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

def conectar_mongo():

    print("Por seguridad, ingresa tu password de Atlas:")
    password = getpass()

    uri = f"mongodb+srv://16kbv1bf_db_user:{password}@cluster0.skazlbe.mongodb.net/?appName=Cluster0"


    # Crea un nuevo cliente y se conecta al servidor
    client = MongoClient(uri, server_api=ServerApi('1'))

    try:
        client.admin.command('ping')
        print("Pinged your deployment. You successfully connected to MongoDB!")

        # Retornamos directamente la base de datos 'laboratorio_mongo'
        return client["laboratorio_mongo"]

    except Exception as e:
        print(f"Error de conexión: {e}")
        return None
db = conectar_mongo()
# Out:
# ...
# Por seguridad, ingresa tu password de Atlas:
# ··········
# Pinged your deployment. You successfully connected to MongoDB!

# %%
from datetime import datetime

def poblar_datos(db):
  db.ventas.drop()
  db.clientes.drop()

# Dataset de Clientes
  db.clientes.insert_many([
    {"_id": 1, "nombre": "Alice", "membresia": "Gold", "pais": "USA"},
    {"_id": 2, "nombre": "Bob", "membresia": "Silver", "pais": "Canada"},
    {"_id": 3, "nombre": "Charlie", "membresia": "Bronze", "pais": "USA"}
])

# Dataset de Ventas
  db.ventas.insert_many([
    {"item": "Laptop", "precio": 1000, "cantidad": 1, "cliente_id": 1, "fecha": datetime(2023, 1, 15), "categoria": "Electrónica"},
    {"item": "Mouse", "precio": 25, "cantidad": 5, "cliente_id": 2, "fecha": datetime(2023, 1, 20), "categoria": "Accesorios"},
    {"item": "Laptop", "precio": 1000, "cantidad": 2, "cliente_id": 3, "fecha": datetime(2023, 2, 10), "categoria": "Electrónica"},
    {"item": "Monitor", "precio": 200, "cantidad": 2, "cliente_id": 1, "fecha": datetime(2023, 2, 15), "categoria": "Electrónica"},
    {"item": "Teclado", "precio": 50, "cantidad": 10, "cliente_id": 2, "fecha": datetime(2023, 3, 5), "categoria": "Accesorios"},
    {"item": "Mouse", "precio": 25, "cantidad": 2, "cliente_id": 1, "fecha": datetime(2023, 3, 10), "categoria": "Accesorios"}
])

print("Datos cargados en 'laboratorio_mongo'.")
# Out:
# Datos cargados en 'laboratorio_mongo'.
